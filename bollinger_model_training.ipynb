# %% [markdown]
# <a href="https://colab.research.google.com/github/hanchen1103/trading_analysis/blob/main/bollinger_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/trading_analysis

# !git clone https://github.com/hanchen1103/trading_analysis

# !pip install -r /content/trading_analysis/requirements.txt

import os

os.chdir('/content/trading_analysis')
# !pip install -r /content/trading_analysis/requirements.txt

# !python3 /content/trading_analysis/algorithm/BollingerBandsCoLab.py
# Out:
# Cloning into 'trading_analysis'...
# remote: Enumerating objects: 4217, done.
# remote: Counting objects: 100% (4217/4217), done.
# remote: Compressing objects: 100% (3559/3559), done.
# remote: Total 4217 (delta 613), reused 4207 (delta 603), pack-reused 0
# Receiving objects: 100% (4217/4217), 37.06 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (613/613), done.
# Updating files: 100% (4453/4453), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 18.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...
# 2023-09-15 05:13:46.454268: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
